# %% [markdown]
# <a href="https://colab.research.google.com/github/ahvblackwelltech/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/LS_DSPT4_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # ASSIGNMENT
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
#
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
import pandas as pd
import numpy as np

# %%
# URL for raw data
url = "https://raw.githubusercontent.com/jvns/pandas-cookbook/master/data/weather_2012.csv"

# %%
df_weather = pd.read_csv(url)
df_weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df_weather['Date/Time'] = pd.to_datetime(df_weather['Date/Time'])

# %%
df_weather.set_index('Date/Time')
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# ...                       ...                 ...          ...
# 2012-12-31 19:00:00       0.1                -2.7           81
# 2012-12-31 20:00:00       0.2                -2.4           83
# 2012-12-31 21:00:00      -0.5                -1.5           93
# 2012-12-31 22:00:00      -0.2                -1.8           89
# 2012-12-31 23:00:00       0.0                -2.1           86
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# ...

# %%
type(df_weather['Date/Time'])
# Out:
# pandas.core.series.Series

# %%
x_list = [1,2,3]
x_arr = np.array([1,2,3])
x_series = pd.Series([1,2,3])

# %%
for i in x_series:
  print(i)
# Out:
# 1
# 2
# 3

# %%
df_weather['Weather'].str.contains('Snow')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779     True
# 8780     True
# 8781     True
# 8782     True
# 8783     True
# Name: Weather, Length: 8784, dtype: bool

# %%
df_weather['Weather'].str.contains('Rain')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
is_precipitation = df_weather['Weather'].str.contains('Rain') | df_weather['Weather'].str.contains('Snow')
is_precipitation
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779     True
# 8780     True
# 8781     True
# 8782     True
# 8783     True
# Name: Weather, Length: 8784, dtype: bool

# %%
df_weather['is_percipitation'] = is_precipitation

# %%
df_weather.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
#
#    is_percipitation
# 0             False
# 1             False
# 2             False
# 3             False
# ...

# %%
df_weather['Visibility (mi)'] = df_weather['Visibility (km)']*0.621

# %%
df_weather.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
#
#    is_percipitation  Visibility (mi)
# 0             False           4.9680
# 1             False           4.9680
# ...

# %% [markdown]
# **LendingClub Dataset**

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-11-02 19:19:22--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [         <=>        ]  21.66M   431KB/s    in 54s
#
# 2019-11-02 19:20:17 (410 KB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [22709125]

# %%
# !unzip LoanStats_2018Q4.csv
# Out:
# Archive:  LoanStats_2018Q4.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# Loaded LendingClub Data
df = pd.read_csv('LoanStats_2018Q4.csv')
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,123,124,125,128,129,130,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    35000.0      35000.0          35000.0   36 months
# 1  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 2  NaN        NaN    10000.0      10000.0          10000.0   60 months
# 3  NaN        NaN    17100.0      17100.0          17100.0   36 months
# 4  NaN        NaN     4000.0       4000.0           4000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0   14.47%      1204.23     C        C2       Staff Physician    8 years
# 1   22.35%       191.86     D        D5     Director of Sales  10+ years
# ...

# %%
df.tail()
# Out:
#                                                       id  member_id  \
# 128409                                               NaN        NaN
# 128410                                               NaN        NaN
# 128411                                               NaN        NaN
# 128412  Total amount funded in policy code 1: 2050909275        NaN
# 128413   Total amount funded in policy code 2: 820109297        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 128409     5000.0       5000.0           5000.0   36 months   13.56%
# 128410    10000.0      10000.0           9750.0   36 months   11.06%
# 128411    10000.0      10000.0          10000.0   36 months   16.91%
# 128412        NaN          NaN              NaN         NaN      NaN
# 128413        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade             emp_title emp_length  \
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3978.52","3978.52","2271.97","2271.97","1621.48","650.49","0.0","0.0","0.0","Oct-2019","190.21","Nov-2019","Oct-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      35000        35000          35000.0   36 months
# 1 NaN        NaN       5000         5000           5000.0   36 months
# 2 NaN        NaN      10000        10000          10000.0   60 months
# 3 NaN        NaN      17100        17100          17100.0   36 months
# 4 NaN        NaN       4000         4000           4000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0   14.47%      1204.23     C        C2       Staff Physician    8 years
# 1   22.35%       191.86     D        D5     Director of Sales  10+ years
# 2   23.40%       284.21     E        E1                   NaN   < 1 year
# 3   18.94%       626.30     D        D2         Receptionist   10+ years
# 4   10.72%       130.43     B        B2  Extrusion assistant   10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
df.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
# 128411 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade             emp_title emp_length  \
# 128407   15.02%       797.53     C        C3        Tax Consultant  10+ years
# 128408   15.02%       346.76     C        C3        security guard    5 years
# 128409   13.56%       169.83     C        C1          Payoff Clerk  10+ years
# 128410   11.06%       327.68     B        B3                   NaN        NaN
# 128411   16.91%       356.08     C        C5  Key Accounts Manager    2 years
#
# ...

# %%
df.shape
# Out:
# (128412, 144)

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
df.isnull().sum()
# Out:
# id                       128412
# member_id                128412
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
#                           ...
# settlement_status        128165
# settlement_date          128165
# settlement_amount        128165
# settlement_percentage    128165
# settlement_term          128165
# Length: 144, dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128412
# desc                                          128412
# member_id                                     128412
# url                                           128412
# orig_projected_additional_accrued_interest    128283
#                                                ...
# inq_last_12m                                       0
# acc_open_past_24mths                               0
# chargeoff_within_12_mths                           0
# delinq_amnt                                        0
# inq_fi                                             0
# Length: 144, dtype: int64

# %%
# Replacing Strings Into Numbers
df.drop(columns=['id', 'member_id', 'desc', 'url'])
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           35000        35000          35000.0   36 months   14.47%
# 1            5000         5000           5000.0   36 months   22.35%
# 2           10000        10000          10000.0   60 months   23.40%
# 3           17100        17100          17100.0   36 months   18.94%
# 4            4000         4000           4000.0   36 months   10.72%
# ...           ...          ...              ...         ...      ...
# 128407      23000        23000          23000.0   36 months   15.02%
# 128408      10000        10000          10000.0   36 months   15.02%
# 128409       5000         5000           5000.0   36 months   13.56%
# 128410      10000        10000           9750.0   36 months   11.06%
# 128411      10000        10000          10000.0   36 months   16.91%
#
#         installment grade sub_grade             emp_title emp_length  \
# ...

# %%
df = df.drop(columns=['id', 'member_id', 'desc', 'url'])

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      35000        35000          35000.0   36 months   14.47%      1204.23
# 1       5000         5000           5000.0   36 months   22.35%       191.86
# 2      10000        10000          10000.0   60 months   23.40%       284.21
# 3      17100        17100          17100.0   36 months   18.94%       626.30
# 4       4000         4000           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2       Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5     Director of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1                   NaN   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist   10+ years           RENT     38000.0
# 4     B        B2  Extrusion assistant   10+ years       MORTGAGE     56000.0
#
# ...

# %%
hardship_cols =[col for col in df.columns if col.startswith('hardship_')]
hardship_cols
# Out:
# ['hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount']

# %%
df.shape
# Out:
# (128412, 140)

# %%
df = df.drop(columns=hardship_cols)

# %%
df.shape
# Out:
# (128412, 128)

# %%
df.describe(exclude='number')
# Out:
#               term int_rate   grade sub_grade emp_title emp_length  \
# count       128412   128412  128412    128412    107465     116708
# unique           2       46       7        35     43892         11
# top      36 months   13.56%       A        A4   Teacher  10+ years
# freq         88179     6972   38011      9770      2090      38826
#
#        home_ownership verification_status   issue_d loan_status pymnt_plan  \
# count          128412              128412    128412      128412     128412
# unique              4                   3         3           7          2
# top          MORTGAGE        Not Verified  Oct-2018     Current          n
# freq            63490               58350     46305      103062     128318
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# ...

# %% [markdown]
# **Converted int_rate from string to a float**

# %%
# Converted int_rate from string to int and floats

df['int_rate']
# Out:
# 0          14.47%
# 1          22.35%
# 2          23.40%
# 3          18.94%
# 4          10.72%
#            ...
# 128407     15.02%
# 128408     15.02%
# 128409     13.56%
# 128410     11.06%
# 128411     16.91%
# Name: int_rate, Length: 128412, dtype: object

# %%
a = '16.91%'
a[:-1]
# Out:
# '16.91'

# %%
a.strip('%')
# Out:
# '16.91'

# %%
b = '%16%.91%'
b.strip('%')
# Out:
# '16%.91'

# %%
b[:-1]
# Out:
# '%16%.91'

# %%
b.replace('%', '')
# Out:
# '16.91'

# %%
float(b.replace('%', ''))
# Out:
# 16.91

# %%
#Applying the function to the int_rate column

def remove_percent_to_float(x):
  return float(x[:-1])

# %%
remove_percent_to_float_v2 = lambda x: float(x[:-1])

# %%
remove_percent_to_float('16.91%')
# Out:
# 16.91

# %%
remove_percent_to_float_v2('16.91%')
# Out:
# 16.91

# %%
a = ['16.91%', '12.23%', '15.75%']
[remove_percent_to_float(i) for i in a]
# Out:
# [16.91, 12.23, 15.75]

# %%
df['int_rate'] = df['int_rate'].apply(remove_percent_to_float)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      35000        35000          35000.0   36 months     14.47      1204.23
# 1       5000         5000           5000.0   36 months     22.35       191.86
# 2      10000        10000          10000.0   60 months     23.40       284.21
# 3      17100        17100          17100.0   36 months     18.94       626.30
# 4       4000         4000           4000.0   36 months     10.72       130.43
#
#   grade sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2       Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5     Director of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1                   NaN   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist   10+ years           RENT     38000.0
# 4     B        B2  Extrusion assistant   10+ years       MORTGAGE     56000.0
#
# ...

# %% [markdown]
# **Converted term from string to a int**

# %%
df['term']
# Out:
# 0          36 months
# 1          36 months
# 2          60 months
# 3          36 months
# 4          36 months
#              ...
# 128407     36 months
# 128408     36 months
# 128409     36 months
# 128410     36 months
# 128411     36 months
# Name: term, Length: 128412, dtype: object

# %%
c = '36 months'
c[:-7]
# Out:
# '36'

# %%
c.strip(' months')
# Out:
# '36'

# %%
c.replace(' months','')
# Out:
# '36'

# %%
int(c.replace(' months', ''))
# Out:
# 36

# %% [markdown]
# **Appliying The Function to "term"**

# %%
def remove_months_to_int(y):
  return int(y[:-7])

# %%
remove_months_to_int_v3 = lambda y: int(y[:-7])

# %%
remove_months_to_int('36 months')
# Out:
# 36

# %%
remove_months_to_int_v3('36 months')
# Out:
# 36

# %%
c = ['36 months', '60 months']
[remove_months_to_int(x) for x in c]
# Out:
# [36, 60]

# %%
df['term'] = df['term'].apply(remove_months_to_int)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      35000        35000          35000.0    36     14.47      1204.23     C
# 1       5000         5000           5000.0    36     22.35       191.86     D
# 2      10000        10000          10000.0    60     23.40       284.21     E
# 3      17100        17100          17100.0    36     18.94       626.30     D
# 4       4000         4000           4000.0    36     10.72       130.43     B
#
#   sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0        C2       Staff Physician    8 years       MORTGAGE    360000.0
# 1        D5     Director of Sales  10+ years       MORTGAGE     72000.0
# 2        E1                   NaN   < 1 year           RENT     55000.0
# 3        D2         Receptionist   10+ years           RENT     38000.0
# 4        B2  Extrusion assistant   10+ years       MORTGAGE     56000.0
#
# ...

# %% [markdown]
# **Cleaning**

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 43892

# %%
df.describe(exclude='number')
# Out:
#          grade sub_grade emp_title emp_length home_ownership  \
# count   128412    128412    107465     116708         128412
# unique       7        35     43892         11              4
# top          A        A4   Teacher  10+ years       MORTGAGE
# freq     38011      9770      2090      38826          63490
#
#        verification_status   issue_d loan_status pymnt_plan  \
# count               128412    128412      128412     128412
# unique                   3         3           7          2
# top           Not Verified  Oct-2018     Current          n
# freq                 58350     46305      103062     128318
#
#                    purpose               title zip_code addr_state  \
# count               128412              128412   128412     128412
# unique                  12                  12      880         50
# top     debt_consolidation  Debt consolidation    112xx         CA
# freq                 70603               70603     1370      17879
#
# ...

# %%
def clean_title(title):
  if isinstance(title, str):
    return title.strip().lower()
  else:
    return 'unknown'

# %%
df['emp_title'] = df['emp_title'].apply(clean_title)

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# unknown               20947
# teacher                2557
# manager                2395
# registered nurse       1418
# driver                 1258
# supervisor             1160
# truck driver            920
# rn                      834
# office manager          805
# sales                   803
# general manager         791
# project manager         720
# owner                   625
# director                523
# operations manager      518
# sales manager           500
# police officer          440
# nurse                   425
# technician              420
# engineer                412
# Name: emp_title, dtype: int64

# %%
type(np.NaN)
# Out:
# float

# %%
df['loan_status_is_great'] = df['loan_status'].str.contains('is_great')

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'payment_plan_start_date', 'orig_projected_additional_accrued_interest',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term', 'loan_status_is_great'],
#       dtype='object', length=129)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      35000        35000          35000.0    36     14.47      1204.23     C
# 1       5000         5000           5000.0    36     22.35       191.86     D
# 2      10000        10000          10000.0    60     23.40       284.21     E
# 3      17100        17100          17100.0    36     18.94       626.30     D
# 4       4000         4000           4000.0    36     10.72       130.43     B
#
#   sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0        C2      staff physician    8 years       MORTGAGE    360000.0
# 1        D5    director of sales  10+ years       MORTGAGE     72000.0
# 2        E1              unknown   < 1 year           RENT     55000.0
# 3        D2         receptionist  10+ years           RENT     38000.0
# 4        B2  extrusion assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
# Loan Status Function

# %%
CT = 'Current'
CT[:-7]
# Out:
# ''

# %%
CT.strip('Current')
# Out:
# ''

# %%
CT.replace('Current', '1')
# Out:
# '1'

# %%
int(CT.replace('Current', '1'))
# Out:
# 1

# %%
FP = 'Fully Paid'
FP.strip('Fully Paid')
# Out:
# ''

# %%
FP.replace('Fully Paid', '1')
# Out:
# '1'

# %%
int(FP.replace('Fully Paid', '1'))
# Out:
# 1

# %%
loan_status = ['Current', 'Fully Paid']

def status_for_loan(x):
    return int(1)

# %%
status_for_loan_v4 = lambda x: int(1)

# %%
status_for_loan('Current')
# Out:
# 1

# %%
status_for_loan_v4('Fully Paid')
# Out:
# 1

# %%
[status_for_loan(x) for x in loan_status]
# Out:
# [1, 1]

# %%
df['term'] = df['term'].apply(status_for_loan)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      35000        35000          35000.0     1     14.47      1204.23     C
# 1       5000         5000           5000.0     1     22.35       191.86     D
# 2      10000        10000          10000.0     1     23.40       284.21     E
# 3      17100        17100          17100.0     1     18.94       626.30     D
# 4       4000         4000           4000.0     1     10.72       130.43     B
#
#   sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0        C2      staff physician    8 years       MORTGAGE    360000.0
# 1        D5    director of sales  10+ years       MORTGAGE     72000.0
# 2        E1              unknown   < 1 year           RENT     55000.0
# 3        D2         receptionist  10+ years           RENT     38000.0
# 4        B2  extrusion assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
df.insert(10, 'last_pymnt_d_month', True)

# %%
df
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0           35000        35000          35000.0     1     14.47      1204.23
# 1            5000         5000           5000.0     1     22.35       191.86
# 2           10000        10000          10000.0     1     23.40       284.21
# 3           17100        17100          17100.0     1     18.94       626.30
# 4            4000         4000           4000.0     1     10.72       130.43
# ...           ...          ...              ...   ...       ...          ...
# 128407      23000        23000          23000.0     1     15.02       797.53
# 128408      10000        10000          10000.0     1     15.02       346.76
# 128409       5000         5000           5000.0     1     13.56       169.83
# 128410      10000        10000           9750.0     1     11.06       327.68
# 128411      10000        10000          10000.0     1     16.91       356.08
#
# ...

# %%
df.insert(10, 'last_pymnt_d_year', False)

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2019-11-02 19:25:08--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.101.125
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.101.125|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  16.4MB/s    in 13s
#
# 2019-11-02 19:25:22 (14.8 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01
